# %%
# import classy module
from classy import Class

# %%
# create instance of the class "Class"
LambdaCDM = Class()
# pass input parameters
LambdaCDM.set({'omega_b':0.0223828,'omega_cdm':0.1201075,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
LambdaCDM.set({'inverse_omega':0,'scalmass_in_planck':0})
LambdaCDM.set({'modes':'s,t','A_s':2.100549e-09,'r':0.01})
LambdaCDM.set({'temperature contributions':'lisw'})
# run class
LambdaCDM.compute()

# create instance of the class "Class"
LambdaCDM1 = Class()
# pass input parameters
LambdaCDM1.set({'omega_b':0.0223828,'omega_cdm':0.1201075,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM1.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
LambdaCDM1.set({'inverse_omega':1,'scalmass_in_planck':1e-8})
LambdaCDM1.set({'modes':'s,t','A_s':2.100549e-09,'r':0.01})
LambdaCDM1.set({'temperature contributions':'lisw'})
# run class
LambdaCDM1.compute()

# create instance of the class "Class"
LambdaCDM2 = Class()
# pass input parameters
LambdaCDM2.set({'omega_b':0.0223828,'omega_cdm':0.1201075,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM2.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
LambdaCDM2.set({'inverse_omega':1,'scalmass_in_planck':2e-8})
LambdaCDM2.set({'modes':'s,t','A_s':2.100549e-09,'r':0.01})
LambdaCDM2.set({'temperature contributions':'lisw'})
# run class
LambdaCDM2.compute()

# create instance of the class "Class"
LambdaCDM3 = Class()
# pass input parameters
LambdaCDM3.set({'omega_b':0.0223828,'omega_cdm':0.1201075,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM3.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
LambdaCDM3.set({'inverse_omega':1,'scalmass_in_planck':3e-8})
LambdaCDM3.set({'modes':'s,t','A_s':2.100549e-09,'r':0.01})
LambdaCDM3.set({'temperature contributions':'lisw'})
# run class
LambdaCDM3.compute()

# create instance of the class "Class"
LambdaCDM4 = Class()
# pass input parameters
LambdaCDM4.set({'omega_b':0.0223828,'omega_cdm':0.1201075,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM4.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
LambdaCDM4.set({'inverse_omega':1,'scalmass_in_planck':4e-8})
LambdaCDM4.set({'modes':'s,t','A_s':2.100549e-09,'r':0.01})
LambdaCDM4.set({'temperature contributions':'lisw'})
# run class
LambdaCDM4.compute()

# %%
# get all C_l output
cls = LambdaCDM.raw_cl(2500)
# To check the format of cls
cls.keys()

# get all C_l output
cls1 = LambdaCDM1.raw_cl(2500)
# To check the format of cls
cls1.keys()

# get all C_l output
cls2 = LambdaCDM2.raw_cl(2500)
# To check the format of cls
cls2.keys()

# get all C_l output
cls3 = LambdaCDM3.raw_cl(2500)
# To check the format of cls
cls3.keys()

# get all C_l output
cls4 = LambdaCDM4.raw_cl(2500)
# To check the format of cls
cls4.keys()
# Out:
# dict_keys(['tt', 'ee', 'te', 'bb', 'pp', 'tp', 'ell'])

# %%
ll = cls['ell'][2:]
clTT = cls['tt'][2:]
clEE = cls['ee'][2:]
clTE = cls['te'][2:]
clBB = cls['bb'][2:]
clPP = cls['pp'][2:]

ll1 = cls1['ell'][2:]
clTT1 = cls1['tt'][2:]
clEE1 = cls1['ee'][2:]
clTE1 = cls1['te'][2:]
clBB1 = cls1['bb'][2:]
clPP1 = cls1['pp'][2:]

ll2 = cls2['ell'][2:]
clTT2 = cls2['tt'][2:]
clEE2 = cls2['ee'][2:]
clTE2 = cls2['te'][2:]
clBB2 = cls2['bb'][2:]
clPP2 = cls2['pp'][2:]

ll3 = cls3['ell'][2:]
clTT3 = cls3['tt'][2:]
clEE3 = cls3['ee'][2:]
clTE3 = cls3['te'][2:]
clBB3 = cls3['bb'][2:]
clPP3 = cls3['pp'][2:]

ll4 = cls4['ell'][2:]
clTT4 = cls4['tt'][2:]
clEE4 = cls4['ee'][2:]
clTE4 = cls4['te'][2:]
clBB4 = cls4['bb'][2:]
clPP4 = cls4['pp'][2:]

# %%
# uncomment to get plots displayed in notebook
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from math import pi
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

font = {'size'   : 16, 'family':'Times New Roman'}
axislabelfontsize='large'
matplotlib.rc('font', **font)
matplotlib.mathtext.rcParams['legend.fontsize']='medium'
plt.rcParams["figure.figsize"] = [8.0,6.0]

# %%
# plot C_l^TT
plt.figure(1)
plt.xscale('log');plt.yscale('linear');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$10^{10} [\ell(\ell+1)/2\pi]  C_\ell^\mathrm{TT}$')
plt.plot(ll,10**10*clTT*ll*(ll+1)/2./pi,label=r'$\Lambda$CDM')
plt.plot(ll1,10**10*clTT1*ll1*(ll1+1)/2./pi,label=r'$m_{\varphi}=1\times10^{-8} M_\mathrm{P}$')
plt.plot(ll2,10**10*clTT2*ll2*(ll2+1)/2./pi,label=r'$m_{\varphi}=2\times10^{-8} M_\mathrm{P}$')
plt.plot(ll3,10**10*clTT3*ll3*(ll3+1)/2./pi,label=r'$m_{\varphi}=3\times10^{-8} M_\mathrm{P}$')
plt.plot(ll4,10**10*clTT4*ll4*(ll4+1)/2./pi,label=r'$m_{\varphi}=4\times10^{-8} M_\mathrm{P}$')

plt.title(r'late-time ISW effect part of $C_\ell^\mathrm{TT}$ with varying $m_{\varphi}$')
plt.grid()
plt.legend(loc='upper right')
plt.savefig('cltt_lisw.png',bbox_inches='tight')

# %%
# optional: reset parameters to default in case you want 
# to set different parameters and rerun LambdaCDM.compute()
LambdaCDM.empty()
